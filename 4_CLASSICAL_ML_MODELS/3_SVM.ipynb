# %% [markdown]
# # ***Engr.Muhammad Javed***

# %% [markdown]
# # 3. Support Vector Machine (SVM)
#
# Finds the hyperplane that best separates the classes.
# - **LinearSVC:** Faster for text.
# - **SVC:** Can use kernels but slower on large datasets.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

# Load Data
df_train = pd.read_csv('../Dataset/train.txt', sep=';', names=['text', 'emotion'])
df_test = pd.read_csv('../Dataset/test.txt', sep=';', names=['text', 'emotion'])

# Preprocess
vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])
y_train = df_train['emotion']
y_test = df_test['emotion']

# Train
svm = LinearSVC()
svm.fit(X_train, y_train)

# Evaluate
y_pred = svm.predict(X_test)
print("SVM Accuracy:", accuracy_score(y_test, y_pred))
