# %% [markdown]
# # ***Engr.Muhammad Javed***

# %% [markdown]
# # 6. Text Normalization
#
# Normalization puts text into a standard format.
#
# ## 1. Case Normalization
# (Covered in Cleaning - using lowercasing)
#
# ## 2. Contraction Expansion
# Expanding words like "don't" to "do not".

# %%
import re

contractions_dict = {
    "don't": "do not",
    "can't": "cannot",
    "won't": "will not",
    "i'm": "i am",
    "it's": "it is"
}

def expand_contractions(text, contraction_mapping=contractions_dict):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)
        if not expanded_contraction:
            expanded_contraction = contraction_mapping.get(match.lower())
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    return expanded_text

print(expand_contractions("I'm going to the park. It's nice."))
# Out:
# i am going to the park. it is nice.

# %% [markdown]
# ## 3. Spelling Correction

# %%
try:
    from textblob import TextBlob
    text = "I havv good speling."
    print("Original:", text)
    print("Corrected:", str(TextBlob(text).correct()))
except ImportError:
    print("TextBlob not installed. Install with `pip install textblob`")
# Out:
# Original: I havv good speling.
# Corrected: I have good spelling.
